# %% [markdown]
# ## Goal: to analyse historical data

# %%
from api_utils import get_json_from_api
import pandas as pd
import seaborn as sns

# %%
element_json = get_json_from_api('http://fantasy.premierleague.com/api/bootstrap-static/')
player_json = get_json_from_api('https://fantasy.premierleague.com/api/element-summary/234/')

# %%
element_df = pd.DataFrame(element_json['elements'])
df = pd.DataFrame(player_json['history_past'])
element_df
# Out:
#      chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                             NaN                           NaN   80201
# 1                           100.0                         100.0  115918
# 2                            75.0                          50.0   47431
# 3                           100.0                         100.0   54694
# 4                             NaN                           NaN   58822
# ..                            ...                           ...     ...
# 572                           NaN                           NaN  149065
# 573                           0.0                           0.0  209353
# 574                           NaN                           NaN  245923
# 575                           NaN                           NaN  461026
# 576                           NaN                           NaN  481626
#
#      cost_change_event  cost_change_event_fall  cost_change_start  \
# ...

# %%
df.columns
element_json.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
df
# Out:
#   season_name  element_code  start_cost  end_cost  total_points  minutes  \
# 0     2014/15        122798          45        42            45     1526
# 1     2016/17        122798          45        44            73     2736
# 2     2017/18        122798          50        50           111     1940
# 3     2018/19        122798          60        67           213     3216
# 4     2019/20        122798          70        70           181     3111
# 5     2020/21        122798          70        73           161     3384
#
#    goals_scored  assists  clean_sheets  goals_conceded  ...  penalties_missed  \
# 0             0        2             3              27  ...                 0
# 1             1        2             5              59  ...                 0
# 2             1        5            10              18  ...                 0
# 3             0       12            21              20  ...                 0
# ...
